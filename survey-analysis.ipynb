# %%
# %matplotlib widget
import pandas as pd
from pathlib import Path
from pandas.api.types import CategoricalDtype
import matplotlib.pyplot as plt
import geopandas

from utils import annotate_plot

# %%
response_file = Path("responses.csv")
data = pd.read_csv(
    response_file, skiprows=[0, 1], header=None, index_col=0, dtype=object
)
drop_rows = [
    "3pcu3xeho94or13fmgo3pcu3vu7ufm3r",
    "gbeoi35j09sxzk2295regbeoi35w9xsn",
    "h3s656mrygc53ln0hik2h3s65acyqwhx",
]
data = data.drop(drop_rows)

# %%
operating_systems = [
    "macOS",
    "BSD",
    "Windows 7",
    "Windows 10",
    "Debian or its derivatives (Ubuntu, Mint, etc.)",
    "Red Hat or its derivatives (Fedora, CentOS, etc.)",
    "Other",
]
interfaces = ["Python", "MATLAB", "C++", "C", "Fortran"]
install_methods = [
    "I don't update",
    "Somebody else manages it for me",
    "Anaconda",
    "Build from source (via GitHub)",
    "Windows binaries (.msi file), downloaded from GitHub",
    "macOS installer (.pkg file), downloaded from GitHub",
    "Ubuntu Personal Package Archive (PPA)",
    "Other",
]
frequency = CategoricalDtype(["Often", "Sometimes", "Rarely", "Never"])

# %%
interface_data = data[range(8, 13)]
interface_data.columns = interfaces
n_responses = len(interface_data.index)
fig, ax = plt.subplots()
(interface_data.count().sort_index() / n_responses).plot.barh(ax=ax)
annotate_plot(
    ax,
    f"Which interface(s) do you use to access Cantera? {n_responses} Responses",
    n_responses,
)

# %%
fig, ax = plt.subplots()
os_data = data[range(1, 8)]
os_data.columns = operating_systems
n_responses = len(os_data.index)
(os_data.count().sort_index() / n_responses).plot.barh(ax=ax)
annotate_plot(
    ax, f"What operating system(s) do you use? {n_responses} Responses", n_responses
)

# %%
fig, ax = plt.subplots()
install_data = data[range(13, 21)]
install_data.columns = install_methods
n_responses = len(install_data.index)
(install_data.count().sort_index() / n_responses).plot.barh(ax=ax, fontsize=5)
annotate_plot(
    ax,
    "Do you use the following sources to install and/or upgrade Cantera?",
    n_responses,
)

# %%
fig, ax = plt.subplots()
ct_versions = CategoricalDtype(
    [
        "2.4 (released Aug. 2018)",
        "2.3 (released Jan. 2017)",
        "2.2 (released Jan. 2016)",
        "2.1 (released Apr. 2015)",
        "Older than 2.1",
        "Development version / master branch",
        "I’m not sure",
    ]
)
ct_version_data = data[21].dropna().astype(ct_versions)
n_responses = len(ct_version_data.index)
(ct_version_data.value_counts().sort_index() / n_responses).plot.barh(ax=ax)
annotate_plot(ax, "What version of Cantera do you use most often?", n_responses)

# %%
fig, ax = plt.subplots()
python_freq_data = data[22].fillna("Never").astype(frequency)
n_responses = len(python_freq_data.index)
(python_freq_data.value_counts().sort_index() / n_responses).plot.barh(ax=ax)
annotate_plot(ax, "How often do you use the Python interface?", n_responses)

# %%
fig, ax = plt.subplots()
python_versions = CategoricalDtype(["None"] + [f"3.{x}" for x in [5, 6, 7, 8]])
python_ver_data = data[23].fillna("None").astype(python_versions)
n_responses = len(python_ver_data.index)
(python_ver_data.value_counts().sort_index() / n_responses).plot.barh(ax=ax)
annotate_plot(ax, "Which version of Python do you use the most?", n_responses)

# %%
fig, ax = plt.subplots()
matlab_freq_data = data[24].fillna("Never").astype(frequency)
n_responses = len(matlab_freq_data.index)
(matlab_freq_data.value_counts().sort_index() / n_responses).plot.barh(ax=ax)
annotate_plot(ax, "How often do you use the MATLAB interface?", n_responses)

# %%
fig, ax = plt.subplots()
py_mat_freq_data = data[[22, 24]].fillna("Never").astype(frequency)
n_responses = len(py_mat_freq_data.index)
(py_mat_freq_data.apply(pd.Series.value_counts).sort_index() / n_responses).plot.barh(ax=ax)
ax.legend(["Python", "MATLAB"])
annotate_plot(
    ax, f"How often do you use the X interface? {n_responses} Responses", n_responses
)

# %%
fig, ax = plt.subplots()
continents = pd.CategoricalDtype(
    [
        "Africa",
        "Antarctica",
        "Asia",
        "Australia",
        "Europe",
        "North America",
        "South America",
    ]
)
location = data[105].astype(continents)
n_responses = len(location.index)
(location.value_counts().sort_index() / n_responses).plot.barh(ax=ax)
annotate_plot(ax, f"Where do you live? {n_responses} Responses", n_responses)

# %%
fig, ax = plt.subplots()
support = data[98].astype("category")
n_responses = len(support.index)
(support.value_counts().sort_index() / n_responses).plot.barh(ax=ax)
annotate_plot(
    ax,
    f"When you need help with Cantera, what is your_ first_ step to get support? {n_responses} Responses",
    n_responses,
)

# %%
fig, ax = plt.subplots()
donation = data[97].astype("category")
n_responses = len(donation.index)
donation.value_counts(normalize=True).sort_index().plot.barh(ax=ax)
annotate_plot(
    ax,
    f"Have you ever made a tax-deductible donation to Cantera through NumFOCUS? {n_responses} Responses",
    n_responses,
)

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
world.plot(ax=ax, color='white', edgecolor='black');

# %%
users = [
    {"name": "Louisiana State University", "Latitude":30.4132579 , "Longitude": -91.182191},
    {"name": "Oak Ridge National Laboratory", "Latitude": 35.9411409, "Longitude": -84.3275049},
    {"name": "California State University, Los Angeles", "Latitude": 34.0636856, "Longitude": -118.1685726},
    {"name": "Middle East Technical University", "Latitude": 39.8898382, "Longitude": 32.7778973},
    {"name": "Siemens", "Latitude": 41.4249373, "Longitude": -73.2276351},
    {"name": "Streamline Numerics, Inc.",},
    {"name": "ArcelorMittal",},
    {"name": "Zhejiang University",},
    {"name": "NIST",},
    {"name": "MiT",},
    {"name": "Georgia Institute of Technoloy",},
    {"name": "Shell",},
    {"name": "Northeastern University",},
    {"name": "Colorado School of Mines",},
    {"name": "University of Connecticut",},
    {"name": "University of Vaasa",},
    {"name": "Innovative Scientific Solutions Inc.",},
    {"name": "Purdue University",},
    {"name": "KIT",},
    {"name": "Warsaw university of technology",},
    {"name": "Oregon State University",},
    {"name": "LBS",},
    {"name": "Linde",},
    {"name": "National University of Ireland, Galway",},
    {"name": "Cascade Technologies",},
    {"name": "University of Canterbury",},
    {"name": "Argonne National Laboratory",},
    {"name": "Aalborg University",},
    {"name": "Hunan University, China",},
    {"name": "BASF",},
    {"name": "Trinity College Dublin",},
    {"name": "University of California, Los Angeles",},
    {"name": "Federal University of Pampa (UNIPAMPA)",},
    {"name": "Columbia University",},
    {"name": "University of Caen",},
    {"name": "Loughborough University",},
]

users = pd.DataFrame(users)

# %%
gdf = geopandas.GeoDataFrame(
    users, geometry=geopandas.points_from_xy(users.Longitude, users.Latitude))

# %%
gdf.plot(ax=ax, color='b');

# %%
fig, ax = plt.subplots()
employment = data[107].astype("category").dropna()
n_responses = len(employment.index)
employment.value_counts(normalize=True).sort_index().plot.barh(ax=ax)
annotate_plot(
    ax,
    f"What is your employment status? {n_responses} Responses",
    n_responses,
)
fig.tight_layout()

# %%
# fig, ax = plt.subplots()
priority_responses = CategoricalDtype([
    "New thermodynamics, kinetics, or transport models",
    "Equilibrium solvers - performance",
    "Equilibrium solvers - robustness",
    "Reactor networks - performance",
    "Reactor networks - robustness",
    "1D solver - performance",
    "1D solver - robustness",
    "Feature and model documentation",
    "Examples and tutorials",
    "Python interface",
    "Matlab interface",
    "Fortran interface",
    "New language interfaces (for example, Julia)",
    "New reactor or flow types (for example, transient 1-D or plug flow)",
    "Improvement of ReactionPathDiagram",
    "Updated and Comprehensive Documentation for FORTRAN interface",
    "Adjoint Sensitivity Analysis",
])
priorities = data[range(83, 89)]
priorities.head()
# Out:
#                                                                                  83  \
# 0
# r2w0retelulfeavbz8nkr2w04hf2b6nx                                   Python interface
# twg8u7g64abr2oatwg8ucv1b7s986kai                             Examples and tutorials
# tka9zbm6vm95yi8htka9z4pw4f40lsi4                      Reactor networks - robustness
# 1ye8f3owozejbsniw71ye8fh0bss35gw                             Examples and tutorials
# wm9wegazlc9lec5q2rp9wm9weqhfph4m  New reactor or flow types (for example, transi...
#
#                                    84  \
# 0
# r2w0retelulfeavbz8nkr2w04hf2b6nx  NaN
# twg8u7g64abr2oatwg8ucv1b7s986kai  NaN
# tka9zbm6vm95yi8htka9z4pw4f40lsi4  NaN
# 1ye8f3owozejbsniw71ye8fh0bss35gw  NaN
# wm9wegazlc9lec5q2rp9wm9weqhfph4m  NaN
#
#                                                                                  85  \
# 0
# r2w0retelulfeavbz8nkr2w04hf2b6nx                      Reactor networks - robustness
# twg8u7g64abr2oatwg8ucv1b7s986kai  New reactor or flow types (for example, transi...
# tka9zbm6vm95yi8htka9z4pw4f40lsi4  New thermodynamics, kinetics, or transport models
# 1ye8f3owozejbsniw71ye8fh0bss35gw                    Feature and model documentation
# wm9wegazlc9lec5q2rp9wm9weqhfph4m                      Reactor networks - robustness
#
#                                    86  \
# 0
# r2w0retelulfeavbz8nkr2w04hf2b6nx  NaN
# twg8u7g64abr2oatwg8ucv1b7s986kai  NaN
# tka9zbm6vm95yi8htka9z4pw4f40lsi4  NaN
# 1ye8f3owozejbsniw71ye8fh0bss35gw  NaN
# wm9wegazlc9lec5q2rp9wm9weqhfph4m  NaN
#
#                                                                                  87  \
# 0
# r2w0retelulfeavbz8nkr2w04hf2b6nx                             Examples and tutorials
# twg8u7g64abr2oatwg8ucv1b7s986kai                             1D solver - robustness
# tka9zbm6vm95yi8htka9z4pw4f40lsi4                   Equilibrium solvers - robustness
# 1ye8f3owozejbsniw71ye8fh0bss35gw  New reactor or flow types (for example, transi...
# wm9wegazlc9lec5q2rp9wm9weqhfph4m                     Reactor networks - performance
#
#                                    88
# 0
# r2w0retelulfeavbz8nkr2w04hf2b6nx  NaN
# twg8u7g64abr2oatwg8ucv1b7s986kai  NaN
# tka9zbm6vm95yi8htka9z4pw4f40lsi4  NaN
# 1ye8f3owozejbsniw71ye8fh0bss35gw  NaN
# wm9wegazlc9lec5q2rp9wm9weqhfph4m  NaN

# %%
highest = pd.merge(priorities[83].value_counts(), priorities[84].value_counts(), left_index=True, right_index=True)

# %%
highest.dtypes

# %%
middle = pd.DataFrame(pd.concat((priorities[85].value_counts(), priorities[86].value_counts())), columns=["Middle"])

# %%
middle.dtypes

# %%
priorities["Highest"] = priorities[83] + priorities[84]

# %%
priorities["Highest"] = priorities[[83, 84]].values[~np.isnan(priorities[[83, 84]].values)]

# %%
import numpy as np

# %%
priorities.loc[pd.isna(priorities[83]), 83] = priorities.loc[~pd.isna(priorities[84]), 84]

# %%
priorities[83]

# %%
priorities[84]

# %%
mask = pd.isna(priorities[83])

# %%
priorities["Highest"] = priorities[83].fillna(priorities[84])
priorities["Middle"] = priorities[85].fillna(priorities[86])
priorities["Lowest"] = priorities[87].fillna(priorities[88])
# Out:
# <ipython-input-13-3dd4258f05f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priorities["Highest"] = priorities[83].fillna(priorities.loc[:, 84])
# <ipython-input-13-3dd4258f05f3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priorities["Middle"] = priorities[85].fillna(priorities.loc[:, 86])
# <ipython-input-13-3dd4258f05f3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priorities["Lowest"] = priorities[87].fillna(priorities.loc[:, 88])

# %%
priorities.loc[:, ("Highest", "Middle", "Lowest")]
# Out:
#                                                                             Highest  \
# 0
# r2w0retelulfeavbz8nkr2w04hf2b6nx                                   Python interface
# twg8u7g64abr2oatwg8ucv1b7s986kai                             Examples and tutorials
# tka9zbm6vm95yi8htka9z4pw4f40lsi4                      Reactor networks - robustness
# 1ye8f3owozejbsniw71ye8fh0bss35gw                             Examples and tutorials
# wm9wegazlc9lec5q2rp9wm9weqhfph4m  New reactor or flow types (for example, transi...
# qec8q0jidspzgbqec8y2l54mpbhndmv9                             1D solver - robustness
# dqpb6tpqd8wyk4t8vdqpb6b4bmrxbw3s                      Reactor networks - robustness
# 27ca0l3byvqo1o1u6ps627cmdxl0b8b3                     Reactor networks - performance
# g25e7r3qhr3q9wlsyg25e7zg2mkn3nvj                            1D solver - performance
# 84h4yz86is650mt6rvx84h4yzttmijlq                   Equilibrium solvers - robustness
# 2o5qovwbt5qim2o5q5vz5zw62r98w1ll  New thermodynamics, kinetics, or transport models
# nfbwnch6vljvj0nfbwncnddyc6gqzd2j                    Feature and model documentation
# e5kbebhihrx5voigae5kbebfgjes0045                     Reactor networks - performance
# 4u4hawhlns8jap1qu4u4haz2hio148qh  New thermodynamics, kinetics, or transport models
# 3iapusv1o63hmfrbwgfy3iapuszjhv65                            1D solver - performance
# xii3pi4zvn0nj56a9xii3pienlt7af67                            1D solver - performance
# xs0tme51c3w6w90yff829xs0tmwyl8bg                            1D solver - performance
# 7and3n85zkqsgrv0p7and35zdt3g2eer  New thermodynamics, kinetics, or transport models
# 934aak7byhb7fsw8934aas442f5smdpo  New reactor or flow types (for example, transi...
# 4n56eed4416hr6hwf07m4n56eenz86ki  New thermodynamics, kinetics, or transport models
# ym67515uni3m4duym6751lijtazxppbm                                   MATLAB interface
# 6kltf6wic99qjdx3uap6kltijyn96703                                  Fortran interface
# 0no00fqysynmxvyqpo0no00o1mmsis4e                             1D solver - robustness
# aeft5sb1qke6chhrt90aeft5s7h2l1ox  New reactor or flow types (for example, transi...
# 0jkdoxnfclspba60v0jkdo8wp6cgbt51  New thermodynamics, kinetics, or transport models
# 6d6a7e79q6e87qq86d6a7p1gujfr5rbg                                   Python interface
# xnpzmymt1hrcjlpxnpzm7qgf7zqf5mjc                      Reactor networks - robustness
# fthmeqca56gxna906vdfthmeqpnv02eg                     Reactor networks - performance
# mk0jcf3l5fm04mk0voitmhl1w2djpn22                             Examples and tutorials
# p4xqtdx19mavmgfriyizp4xqtci6lwpx  New thermodynamics, kinetics, or transport models
# j2tnme0yh7beo45izej2tnm3ehawm7lu                      Reactor networks - robustness
# pn2ptkfldn2skyd4pn2p6q5bz2kica0o  New thermodynamics, kinetics, or transport models
# d242ln4b6iil3gvaqd0d242g3tkefr9o  New thermodynamics, kinetics, or transport models
# w37dm0c92wshl9w36ojb2yq4geczzf3v  New thermodynamics, kinetics, or transport models
# gtcmqbtna5vj5js6nc60w2gtcmqbh69k                            1D solver - performance
# uywbe2us6irai7dazgxuywbehtoabgna  New reactor or flow types (for example, transi...
# fwp5vkt7mpb0dfwp5ceh6rus5ab0svce                                   MATLAB interface
# i4wtufaerbxfpfvi4wtuc7eat8ooftmb                     Reactor networks - performance
# k4lf5tpxqajs7tk4lf5txp3wfi7xcf6c                            1D solver - performance
# clzork6pffpk8m5s8clzorkp8d9y8oip  New reactor or flow types (for example, transi...
# u6pjbh8zqmmlk6b5snfcu6pjbh8mtl7h                    Feature and model documentation
# 7vfy3mp8mf5x8z7vfjjbzpnw0w82qeim                      Reactor networks - robustness
# 10ah8mwy1bqe21ej9d10ah0eyeuu5u4l  New reactor or flow types (for example, transi...
# lcpvzr5mtztpv44tlcpvzatb84tdjib3                                  Fortran interface
# bh6zdac3ajzv2r1xbh6zd14id0g4dokz  New thermodynamics, kinetics, or transport models
# mjrh3xj8dmjif4fs2wamd28mjrh31sar                                   Python interface
# 0wu6jnwmida5am40wu6gfo218o5eqp2n                                   Python interface
# 8jp07t05m07dpm8jp0ua4ptpg6bnl1un  New thermodynamics, kinetics, or transport models
# pxon7h2gp5mb7n5fw7t2m4pxon7hp1mm  New reactor or flow types (for example, transi...
# fp5x646mk87secgr9fp5x0fezflb7sic                            1D solver - performance
# el0k4yemfn6ac4kiklel0k4ypykd539i                    Feature and model documentation
# dzp82fxi21i4q52pzz1mp55dzp82fxfq  New reactor or flow types (for example, transi...
# wtblpfjqrcp8enq6ozwtblpf4qo21f30                 Improvement of ReactionPathDiagram
# wm1vb4u8qq39jkxr9hbwm1v7jx4e5wgj  New reactor or flow types (for example, transi...
# f3zs2kayyky36ucxa9f3zs2u18687w7b  New thermodynamics, kinetics, or transport models
# fuaohpki6ta71618bp7mfuaohpmdos0o                             1D solver - robustness
# p2p25xx0zpxq547ktip2p25a7eu4pkci  New thermodynamics, kinetics, or transport models
#
#                                                                              Middle  \
# 0
# r2w0retelulfeavbz8nkr2w04hf2b6nx                      Reactor networks - robustness
# twg8u7g64abr2oatwg8ucv1b7s986kai  New reactor or flow types (for example, transi...
# tka9zbm6vm95yi8htka9z4pw4f40lsi4  New thermodynamics, kinetics, or transport models
# 1ye8f3owozejbsniw71ye8fh0bss35gw                    Feature and model documentation
# wm9wegazlc9lec5q2rp9wm9weqhfph4m                      Reactor networks - robustness
# qec8q0jidspzgbqec8y2l54mpbhndmv9  New thermodynamics, kinetics, or transport models
# dqpb6tpqd8wyk4t8vdqpb6b4bmrxbw3s  New reactor or flow types (for example, transi...
# 27ca0l3byvqo1o1u6ps627cmdxl0b8b3                            1D solver - performance
# g25e7r3qhr3q9wlsyg25e7zg2mkn3nvj                      Reactor networks - robustness
# 84h4yz86is650mt6rvx84h4yzttmijlq                             1D solver - robustness
# 2o5qovwbt5qim2o5q5vz5zw62r98w1ll                     Reactor networks - performance
# nfbwnch6vljvj0nfbwncnddyc6gqzd2j                                   MATLAB interface
# e5kbebhihrx5voigae5kbebfgjes0045                      Reactor networks - robustness
# 4u4hawhlns8jap1qu4u4haz2hio148qh                    Feature and model documentation
# 3iapusv1o63hmfrbwgfy3iapuszjhv65                             1D solver - robustness
# xii3pi4zvn0nj56a9xii3pienlt7af67                             Examples and tutorials
# xs0tme51c3w6w90yff829xs0tmwyl8bg  New thermodynamics, kinetics, or transport models
# 7and3n85zkqsgrv0p7and35zdt3g2eer                                   Python interface
# 934aak7byhb7fsw8934aas442f5smdpo                            1D solver - performance
# 4n56eed4416hr6hwf07m4n56eenz86ki                    Feature and model documentation
# ym67515uni3m4duym6751lijtazxppbm  New reactor or flow types (for example, transi...
# 6kltf6wic99qjdx3uap6kltijyn96703                             Examples and tutorials
# 0no00fqysynmxvyqpo0no00o1mmsis4e  New thermodynamics, kinetics, or transport models
# aeft5sb1qke6chhrt90aeft5s7h2l1ox                             1D solver - robustness
# 0jkdoxnfclspba60v0jkdo8wp6cgbt51                     Reactor networks - performance
# 6d6a7e79q6e87qq86d6a7p1gujfr5rbg  New thermodynamics, kinetics, or transport models
# xnpzmymt1hrcjlpxnpzm7qgf7zqf5mjc                    Feature and model documentation
# fthmeqca56gxna906vdfthmeqpnv02eg                    Feature and model documentation
# mk0jcf3l5fm04mk0voitmhl1w2djpn22                     Reactor networks - performance
# p4xqtdx19mavmgfriyizp4xqtci6lwpx  New reactor or flow types (for example, transi...
# j2tnme0yh7beo45izej2tnm3ehawm7lu                             Examples and tutorials
# pn2ptkfldn2skyd4pn2p6q5bz2kica0o                             1D solver - robustness
# d242ln4b6iil3gvaqd0d242g3tkefr9o                   Equilibrium solvers - robustness
# w37dm0c92wshl9w36ojb2yq4geczzf3v                    Feature and model documentation
# gtcmqbtna5vj5js6nc60w2gtcmqbh69k                             1D solver - robustness
# uywbe2us6irai7dazgxuywbehtoabgna  New thermodynamics, kinetics, or transport models
# fwp5vkt7mpb0dfwp5ceh6rus5ab0svce                             Examples and tutorials
# i4wtufaerbxfpfvi4wtuc7eat8ooftmb                    Feature and model documentation
# k4lf5tpxqajs7tk4lf5txp3wfi7xcf6c  New reactor or flow types (for example, transi...
# clzork6pffpk8m5s8clzorkp8d9y8oip  New thermodynamics, kinetics, or transport models
# u6pjbh8zqmmlk6b5snfcu6pjbh8mtl7h                             Examples and tutorials
# 7vfy3mp8mf5x8z7vfjjbzpnw0w82qeim                     Reactor networks - performance
# 10ah8mwy1bqe21ej9d10ah0eyeuu5u4l  New thermodynamics, kinetics, or transport models
# lcpvzr5mtztpv44tlcpvzatb84tdjib3  New thermodynamics, kinetics, or transport models
# bh6zdac3ajzv2r1xbh6zd14id0g4dokz                             Examples and tutorials
# mjrh3xj8dmjif4fs2wamd28mjrh31sar                                   Python interface
# 0wu6jnwmida5am40wu6gfo218o5eqp2n  New reactor or flow types (for example, transi...
# 8jp07t05m07dpm8jp0ua4ptpg6bnl1un  New reactor or flow types (for example, transi...
# pxon7h2gp5mb7n5fw7t2m4pxon7hp1mm  New thermodynamics, kinetics, or transport models
# fp5x646mk87secgr9fp5x0fezflb7sic  New thermodynamics, kinetics, or transport models
# el0k4yemfn6ac4kiklel0k4ypykd539i  New reactor or flow types (for example, transi...
# dzp82fxi21i4q52pzz1mp55dzp82fxfq  New thermodynamics, kinetics, or transport models
# wtblpfjqrcp8enq6ozwtblpf4qo21f30                    Feature and model documentation
# wm1vb4u8qq39jkxr9hbwm1v7jx4e5wgj                     Reactor networks - performance
# f3zs2kayyky36ucxa9f3zs2u18687w7b                                   Python interface
# fuaohpki6ta71618bp7mfuaohpmdos0o  New reactor or flow types (for example, transi...
# p2p25xx0zpxq547ktip2p25a7eu4pkci                      Reactor networks - robustness
#
#                                                                              Lowest
# 0
# r2w0retelulfeavbz8nkr2w04hf2b6nx                             Examples and tutorials
# twg8u7g64abr2oatwg8ucv1b7s986kai                             1D solver - robustness
# tka9zbm6vm95yi8htka9z4pw4f40lsi4                   Equilibrium solvers - robustness
# 1ye8f3owozejbsniw71ye8fh0bss35gw  New reactor or flow types (for example, transi...
# wm9wegazlc9lec5q2rp9wm9weqhfph4m                     Reactor networks - performance
# qec8q0jidspzgbqec8y2l54mpbhndmv9                                   Python interface
# dqpb6tpqd8wyk4t8vdqpb6b4bmrxbw3s  New thermodynamics, kinetics, or transport models
# 27ca0l3byvqo1o1u6ps627cmdxl0b8b3  New reactor or flow types (for example, transi...
# g25e7r3qhr3q9wlsyg25e7zg2mkn3nvj                             1D solver - robustness
# 84h4yz86is650mt6rvx84h4yzttmijlq  New thermodynamics, kinetics, or transport models
# 2o5qovwbt5qim2o5q5vz5zw62r98w1ll  New reactor or flow types (for example, transi...
# nfbwnch6vljvj0nfbwncnddyc6gqzd2j                             Examples and tutorials
# e5kbebhihrx5voigae5kbebfgjes0045                    Feature and model documentation
# 4u4hawhlns8jap1qu4u4haz2hio148qh                             Examples and tutorials
# 3iapusv1o63hmfrbwgfy3iapuszjhv65  New reactor or flow types (for example, transi...
# xii3pi4zvn0nj56a9xii3pienlt7af67  New thermodynamics, kinetics, or transport models
# xs0tme51c3w6w90yff829xs0tmwyl8bg                     Reactor networks - performance
# 7and3n85zkqsgrv0p7and35zdt3g2eer                  Equilibrium solvers - performance
# 934aak7byhb7fsw8934aas442f5smdpo                      Reactor networks - robustness
# 4n56eed4416hr6hwf07m4n56eenz86ki                             Examples and tutorials
# ym67515uni3m4duym6751lijtazxppbm                    Feature and model documentation
# 6kltf6wic99qjdx3uap6kltijyn96703  Updated and Comprehensive Documentation for FO...
# 0no00fqysynmxvyqpo0no00o1mmsis4e                    Feature and model documentation
# aeft5sb1qke6chhrt90aeft5s7h2l1ox                            1D solver - performance
# 0jkdoxnfclspba60v0jkdo8wp6cgbt51                             Examples and tutorials
# 6d6a7e79q6e87qq86d6a7p1gujfr5rbg                  Equilibrium solvers - performance
# xnpzmymt1hrcjlpxnpzm7qgf7zqf5mjc                             Examples and tutorials
# fthmeqca56gxna906vdfthmeqpnv02eg  New reactor or flow types (for example, transi...
# mk0jcf3l5fm04mk0voitmhl1w2djpn22                    Feature and model documentation
# p4xqtdx19mavmgfriyizp4xqtci6lwpx                                   Python interface
# j2tnme0yh7beo45izej2tnm3ehawm7lu  New reactor or flow types (for example, transi...
# pn2ptkfldn2skyd4pn2p6q5bz2kica0o  New reactor or flow types (for example, transi...
# d242ln4b6iil3gvaqd0d242g3tkefr9o       New language interfaces (for example, Julia)
# w37dm0c92wshl9w36ojb2yq4geczzf3v                             Examples and tutorials
# gtcmqbtna5vj5js6nc60w2gtcmqbh69k                       Adjoint Sensitivity Analysis
# uywbe2us6irai7dazgxuywbehtoabgna                             Examples and tutorials
# fwp5vkt7mpb0dfwp5ceh6rus5ab0svce                             1D solver - robustness
# i4wtufaerbxfpfvi4wtuc7eat8ooftmb                             Examples and tutorials
# k4lf5tpxqajs7tk4lf5txp3wfi7xcf6c  New thermodynamics, kinetics, or transport models
# clzork6pffpk8m5s8clzorkp8d9y8oip                             Examples and tutorials
# u6pjbh8zqmmlk6b5snfcu6pjbh8mtl7h                                   Python interface
# 7vfy3mp8mf5x8z7vfjjbzpnw0w82qeim                             Examples and tutorials
# 10ah8mwy1bqe21ej9d10ah0eyeuu5u4l                     Reactor networks - performance
# lcpvzr5mtztpv44tlcpvzatb84tdjib3                     Reactor networks - performance
# bh6zdac3ajzv2r1xbh6zd14id0g4dokz                                   Python interface
# mjrh3xj8dmjif4fs2wamd28mjrh31sar                                   Python interface
# 0wu6jnwmida5am40wu6gfo218o5eqp2n                     Reactor networks - performance
# 8jp07t05m07dpm8jp0ua4ptpg6bnl1un                             1D solver - robustness
# pxon7h2gp5mb7n5fw7t2m4pxon7hp1mm                             Examples and tutorials
# fp5x646mk87secgr9fp5x0fezflb7sic  New reactor or flow types (for example, transi...
# el0k4yemfn6ac4kiklel0k4ypykd539i  New thermodynamics, kinetics, or transport models
# dzp82fxi21i4q52pzz1mp55dzp82fxfq                             Examples and tutorials
# wtblpfjqrcp8enq6ozwtblpf4qo21f30                             Examples and tutorials
# wm1vb4u8qq39jkxr9hbwm1v7jx4e5wgj                      Reactor networks - robustness
# f3zs2kayyky36ucxa9f3zs2u18687w7b                             Examples and tutorials
# fuaohpki6ta71618bp7mfuaohpmdos0o                      Reactor networks - robustness
# p2p25xx0zpxq547ktip2p25a7eu4pkci                                   Python interface

# %%
ranking = pd.concat([priorities[i].fillna(priorities[i + 1]) for i in (83, 85, 87)], axis=1).astype(priority_responses)
ranking.columns = ["Highest", "Middle", "Lowest"]
# Out:
# Highest    category
# Middle     category
# Lowest     category
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ranking.apply(pd.Series.value_counts).plot.barh(ax=ax)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
